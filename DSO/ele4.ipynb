# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.graphics.gofplots import qqplot
from scipy.stats import norm
from scipy.optimize import minimize

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Load dataset

# %%
df=pd.read_csv('transformer_data.csv')

print(df.head())

print(df.info())
# Out:
#    time          Y        Ta    S          I
# 0     1  23.496733  7.083333  0.0  15.899541
# 1     2  22.720333  7.116667  0.0  15.861768
# 2     3  22.052700  7.216667  0.0  16.121469
# 3     4  21.538050  7.250000  0.0  15.447628
# 4     5  20.995033  7.316667  0.0  16.258319
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    168 non-null    int64
#  1   Y       168 non-null    float64
#  2   Ta      168 non-null    float64
#  3   S       168 non-null    float64
#  4   I       168 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 6.7 KB
# None

# %% [markdown]
# ### Plot dataset

# %%
# Creating subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

#plt.figure(figsize=(8, 5))
axes[0][0].plot(df['time'], df['Y']*(100/max(df['Y'])), label='Y', marker='1')
axes[0][0].plot(df['time'], df['Ta']*(100/max(df['Ta'])), label='Ta', marker='2')
axes[0][0].plot(df['time'], df['S']*(100/max(df['S'])), label='S', marker='3')
axes[0][0].plot(df['time'], df['I']*(100/max(df['I'])), label='I', marker='4')
axes[0][0].set_xlabel('time')
axes[0][0].set_ylabel('Values')
axes[0][0].set_title('Scaled 4 variables')
axes[0][0].legend()
axes[0][0].grid()

# Plotting the first subplot
axes[0][1].plot(df['time'], df['Y'], label='Y', marker='1', color='blue')
axes[0][1].set_title('Y feature')
axes[0][1].set_xlabel('time')
axes[0][1].set_ylabel('Y')
axes[0][1].grid()
axes[0][1].legend()

# Plotting the second subplot 
axes[1][0].plot(df['time'], df['Ta'], label='Ta', marker='2', color='orange')
axes[1][0].set_title('Ta feature')
axes[1][0].set_xlabel('time')
axes[1][0].set_ylabel('Ta')
axes[1][0].grid()
axes[1][0].legend()

# Plotting the third subplot 
axes[1][1].plot(df['time'], df['I'], label='I', marker='4', color='red')
axes[1][1].set_title('I feature')
axes[1][1].set_xlabel('time')
axes[1][1].set_ylabel('I')
axes[1][1].grid()
axes[1][1].legend()

# Adjusting layout for better visualization
plt.tight_layout()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def kf_logLik_dt(par, df):
    """
    par: vector of parameters
    df: DataFrame with observations and inputs as columns (Y, Ta, S, I)
    par: Could be on the form [A, B1, B2, B3, B4, Q, R]
    """

    # Define matrices
    A = np.array([[par[0]]])  # Transition matrix
    B = np.array([[par[1], par[2], par[3]]])  # Input matrix
    Sigma1lt = np.array([[par[4]]])  # Lower-triangle of system covariance matrix
    Sigma1 = Sigma1lt @ Sigma1lt.T  # System covariance matrix (symmetric positive definite)
    C = np.array([[1]])  # Observation matrix
    Sigma2 = np.array([[par[5]]])  # Observation noise covariance matrix
    X0 = np.array([[20]]) # Initial state

    # Variables
    obs_cols = ["Y"]  # Observation column names
    input_cols = ["Ta", "S", "I"]  # Input column names

    # Pull out data
    Y = df[obs_cols].to_numpy()  # m×T
    U = df[input_cols].to_numpy()  # p×T
    Tn = len(df)

    # Init
    n = A.shape[0]
    x_est = X0  # Start state from initial state
    P_est = np.eye(n) * 1e1  # X0 prior covariance
    logLik = 0

    for t in range(Tn):
        # Prediction step
        x_pred = A @ x_est + B @ U[t, :].reshape(-1, 1)
        P_pred = A @ P_est @ A.T + Sigma1

        # Innovation step
        y_pred = C @ x_pred
        S_t = C @ P_pred @ C.T + Sigma2
        innov = Y[t, :].reshape(-1, 1) - y_pred

        # Log-likelihood contribution
        logLik -= 0.5 * (np.log(2 * np.pi * np.linalg.det(S_t)) + innov.T @ np.linalg.solve(S_t, innov))

        # Update step
        K_t = P_pred @ C.T @ np.linalg.inv(S_t)
        x_est = x_pred + K_t @ innov
        P_est = P_pred - K_t @ C @ P_pred

    return float(logLik)

def estimate_dt(start_par, df, lower=None, upper=None):
    """
    Optimizer wrapper to estimate parameters.
    """
    def negLL(par):
        return -kf_logLik_dt(par, df)

    bounds = None
    if lower is not None and upper is not None:
        bounds = [(l, u) for l, u in zip(lower, upper)]

    result = minimize(
        fun=negLL,
        x0=start_par,
        method='L-BFGS-B',
        bounds=bounds,
        options={'maxiter': 1000, 'disp': True}
    )
    return result

# %%
# Application of functions

# Function to calculate AIC and BIC
def calculate_aic_bic(log_likelihood, num_params, num_obs):
    aic = 2 * num_params - 2 * log_likelihood
    bic = np.log(num_obs) * num_params - 2 * log_likelihood
    return aic, bic

# Function to evaluate model performance
def evaluate_model(df, estimated_params):
    # Extract residuals
    residuals = df['Y'] - (estimated_params[0] * df['Y'].shift(1) + 
                           estimated_params[1] * df['Ta'] + 
                           estimated_params[2] * df['S'] + 
                           estimated_params[3] * df['I'] )
    residuals = residuals.dropna()

    # Plot residuals
    plt.figure(figsize=(12, 6))
    plt.plot(residuals, label='Residuals')
    plt.axhline(0, color='red', linestyle='--')
    plt.title('Residuals')
    plt.legend()
    plt.show()

    # ACF and PACF plots
    plot_acf(residuals, lags=20, title='ACF of Residuals')
    plot_pacf(residuals, lags=20, title='PACF of Residuals')
    plt.show()

    # QQ-plot
    qqplot(residuals, line='s')
    plt.title('QQ-Plot of Residuals')
    plt.show()

    # Calculate AIC and BIC
    log_likelihood = -kf_logLik_dt(estimated_params, df)
    num_params = len(estimated_params)
    num_obs = len(residuals)
    aic, bic = calculate_aic_bic(log_likelihood, num_params, num_obs)

    print(f"AIC: {aic}")
    print(f"BIC: {bic}")

# Example usage
# Define starting parameters and bounds
start_par = [0.5, 0.1, 0.1, 0.1, 0.01, 0.01]  # Example starting values
lower_bounds = [-1, -1, -1, -1, 1e-6, 1e-6]
upper_bounds = [1, 1, 1, 1, 10, 10]

# Estimate parameters
result = estimate_dt(start_par, df, lower=lower_bounds, upper=upper_bounds)
estimated_params = result.x
print("Estimated Parameters:", estimated_params)

# Evaluate model performance
evaluate_model(df, estimated_params)
# Out:
# Estimated Parameters: [8.01100115e-01 1.01739849e-01 2.87129487e-03 2.13482445e-01
#  6.44595543e-01 1.00000000e-06]
# AIC: -320.6211316178698
# BIC: -301.9131687433693

# %% [markdown]
# # EXPLENATION

# %% [markdown]
# In the code, the starting parameters (`start_par`) and bounds (`lower_bounds` and `upper_bounds`) are defined as follows:
#
# ### Starting Parameters (`start_par`)
#
#   ```python
# start_par = [0.5, 0.1, 0.1, 0.1, 0.01, 0.01]  # Example starting values
#  ```

# %% [markdown]
# - This is a list of initial guesses for the parameters to be estimated.
# - The parameters correspond to:
#   1. `A` (Transition matrix coefficient)
#   2. `B1` (Input matrix coefficient for `Ta`)
#   3. `B2` (Input matrix coefficient for `S`)
#   4. `B3` (Input matrix coefficient for `I`)
#   5. `Q` (System covariance matrix component)
#   6. `R` (Observation noise covariance matrix component)
#
# ### Lower Bounds (`lower_bounds`)
#
#   ```python
# lower_bounds = [-1, -1, -1, -1, 1e-6, 1e-6]
#   ```

# %% [markdown]
# - These define the minimum allowable values for each parameter during optimization.
# - For example:
#   - `A`, `B1`, `B2`, and `B3` have a lower bound of `-1`.
#   - `Q` and `R` have a lower bound of `1e-6` to ensure positive definiteness.
#
# ### Upper Bounds (`upper_bounds`)
#
#   ```python
# upper_bounds = [1, 1, 1, 1, 10, 10]
#   ```

# %% [markdown]
# - These define the maximum allowable values for each parameter during optimization.
# - For example:
#   - `A`, `B1`, `B2`, and `B3` have an upper bound of `1`.
#   - `Q` and `R` have an upper bound of `10`.
#
# ### Usage in Optimization
# The bounds are combined into a list of tuples and passed to the `minimize` function:
#
#   ```python
# bounds = [(l, u) for l, u in zip(lower_bounds, upper_bounds)]
# result = minimize(
#     fun=negLL,
#     x0=start_par,
#     method='L-BFGS-B',
#     bounds=bounds,
#     options={'maxiter': 1000, 'disp': True}
# )
#   ```

# %% [markdown]
# This ensures that the optimization process respects the specified parameter constraints.

# %% [markdown]
# ### Explanation of the Missing Parts
#
# #### 1. **Parameter Mapping**
# The parameters in the Kalman filter model are mapped as follows:
# - `A`: Transition matrix (1x1), which governs the evolution of the state over time.
# - `B`: Input matrix (1x3), which maps the inputs (`Ta`, `S`, `I`) to the state.
# - `Q`: System covariance matrix (1x1), representing the process noise.
# - `C`: Observation matrix (1x1), assumed to be `[1]` since `Y` is directly observed.
# - `R`: Observation noise covariance matrix (1x1), representing the measurement noise.
# - `X0`: Initial state, set to `20` in this implementation.
#
# #### 2. **Prediction Step**
# The prediction step estimates the next state and its covariance:
# - **State Prediction**:
#   ```python
#   x_pred = A @ x_est + B @ U[t, :].reshape(-1, 1)
#   ```
#   This predicts the next state based on the current state and inputs.
# - **Covariance Prediction**:
#   ```python
#   P_pred = A @ P_est @ A.T + Sigma1
#   ```
#   This predicts the covariance of the next state, incorporating process noise (`Sigma1`).
#
# #### 3. **Innovation Step**
# The innovation step calculates the difference between the observed and predicted values:
# - **Observation Prediction**:
#   ```python
#   y_pred = C @ x_pred
#   ```
#   This predicts the observation based on the predicted state.
# - **Innovation Covariance**:
#   ```python
#   S_t = C @ P_pred @ C.T + Sigma2
#   ```
#   This computes the covariance of the innovation, incorporating measurement noise (`Sigma2`).
# - **Innovation**:
#   ```python
#   innov = Y[t, :].reshape(-1, 1) - y_pred
#   ```
#   This calculates the innovation, i.e., the difference between the actual and predicted observations.
#
# #### 4. **Log-Likelihood Contribution**
# The log-likelihood is updated at each time step using the innovation and its covariance:
#
#   ```python
# logLik -= 0.5 * (np.log(2 * np.pi * np.linalg.det(S_t)) + innov.T @ np.linalg.solve(S_t, innov))
#   ```

# %% [markdown]
# This term quantifies how well the model explains the observed data.
#
# #### 5. **Update Step**
# The update step refines the state and covariance estimates based on the innovation:
# - **Kalman Gain**:
#   ```python
#   K_t = P_pred @ C.T @ np.linalg.inv(S_t)
#   ```
#   This determines how much weight to give to the innovation.
# - **State Update**:
#   ```python
#   x_est = x_pred + K_t @ innov
#   ```
#   This updates the state estimate using the Kalman gain and innovation.
# - **Covariance Update**:
#   ```python
#   P_est = P_pred - K_t @ C @ P_pred
#   ```
#   This updates the covariance estimate.
#
# #### 6. **Optimizer Wrapper**
# The `estimate_dt` function wraps the Kalman filter log-likelihood in an optimization routine:
# - **Negative Log-Likelihood**:
#   ```python
#   def negLL(par):
#       return -kf_logLik_dt(par, df)
#   ```
#   This negates the log-likelihood for minimization.
# - **Bounds**:
#   ```python
#   bounds = [(l, u) for l, u in zip(lower, upper)]
#   ```
#   These enforce parameter constraints during optimization.
# - **Optimization**:
#   ```python
#   result = minimize(
#       fun=negLL,
#       x0=start_par,
#       method='L-BFGS-B',
#       bounds=bounds,
#       options={'maxiter': 1000, 'disp': True}
#   )
#   ```
#   The `minimize` function estimates the parameters by minimizing the negative log-likelihood.
#
# #### 7. **Model Evaluation**
# The `evaluate_model` function assesses the model's performance:
# - **Residuals**:
#   ```python
#   residuals = df['Y'] - (estimated_params[0] * df['Y'].shift(1) +
#                          estimated_params[1] * df['Ta'] +
#                          estimated_params[2] * df['S'] +
#                          estimated_params[3] * df['I'])
#   ```
#   This calculates the residuals between the observed and predicted values.
# - **Plots**:
#   - Residuals plot.
#   - ACF and PACF plots to check for autocorrelation.
#   - QQ-plot to assess normality of residuals.
# - **AIC and BIC**:
#   ```python
#   aic, bic = calculate_aic_bic(log_likelihood, num_params, num_obs)
#   ```
#   These metrics evaluate model fit, penalizing for complexity.
#
# This explanation covers the key steps and missing details in the code.

# %% [markdown]
# Yes, the matrices in the code are correctly defined for the Kalman filter implementation. Here's why:
#
# ### 1. **Transition Matrix (`A`)**

# %% [markdown]
#   ```python
# A = np.array([[par[0]]])  # Transition matrix
#   ```
#
# - `A` is a 1x1 matrix that governs the evolution of the state over time.
# - It is correctly defined as a single-element matrix, as the state is scalar in this implementation.
#
# ### 2. **Input Matrix (`B`)**

# %% [markdown]
# ```python
# B = np.array([[par[1], par[2], par[3]]])  # Input matrix
# ```
#
# - `B` is a 1x3 matrix that maps the inputs (`Ta`, `S`, `I`) to the state.
# - It is correctly defined to match the three input variables.
#
# ### 3. **System Covariance Matrix (`Sigma1`)**

# %% [markdown]
# ```python
# Sigma1lt = np.array([[par[4]]])  # Lower-triangle of system covariance matrix
# Sigma1 = Sigma1lt @ Sigma1lt.T  # System covariance matrix (symmetric positive definite)
# ```
#
# - `Sigma1` is derived from its lower-triangular component (`Sigma1lt`) to ensure it is symmetric and positive definite.
# - This is a standard approach to define covariance matrices in Kalman filters.
#
# ### 4. **Observation Matrix (`C`)**

# %% [markdown]
# ```python
# C = np.array([[1]])  # Observation matrix
# ```
#
# - `C` is a 1x1 matrix that maps the state to the observation (`Y`).
# - It is correctly defined as `[1]` since the observation is directly proportional to the state.
#
# ### 5. **Observation Noise Covariance Matrix (`Sigma2`)**

# %% [markdown]
# ```python
# Sigma2 = np.array([[par[5]]])  # Observation noise covariance matrix
# ```
#
# - `Sigma2` is a 1x1 matrix representing the variance of the observation noise.
# - It is correctly defined as a scalar matrix.
#
# ### 6. **Initial State (`X0`)**

# %% [markdown]
# ```python
# X0 = np.array([[20]])  # Initial state
# ```
#
# - `X0` is a 1x1 matrix representing the initial state of the system.
# - It is correctly defined as a scalar matrix.
#
# ### 7. **Dimensions Consistency**
# - The dimensions of all matrices are consistent with the Kalman filter equations:
#   - `x_pred = A @ x_est + B @ U[t, :].reshape(-1, 1)` ensures the state prediction is valid.
#   - `P_pred = A @ P_est @ A.T + Sigma1` ensures the covariance prediction is valid.
#   - `y_pred = C @ x_pred` ensures the observation prediction is valid.
#   - `S_t = C @ P_pred @ C.T + Sigma2` ensures the innovation covariance is valid.
#
# ### Conclusion
# The matrices are correctly defined and dimensionally consistent with the Kalman filter framework. This ensures the algorithm works as intended.
